# %% [markdown]
# Seaborn is visualllization library used for diffrent kinds of plots
# plots:
#
#
# Relational plots
#
#
# Categorical plots
#
#
# Distribution plots
#
#
# Matrix plots
#
#
# Regression plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
# %matplotlib inline

# %%
dates = np.arange('1981-01-01','1981-01-11',dtype='datetime64')
dates
# Out:
# array(['1981-01-01', '1981-01-02', '1981-01-03', '1981-01-04',
#        '1981-01-05', '1981-01-06', '1981-01-07', '1981-01-08',
#        '1981-01-09', '1981-01-10'], dtype='datetime64[D]')

# %%
min_temp=[20.7,17.9,18.8,14.6,15.8,15.8,15.8,17.4,21.8,20.0]
max_temp=[34.7,28.9,31.8,25.6,28.8,21.8,22.8,28.8,30.8,32.0]
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(15,10))
axes.plot(dates,min_temp,label='Min Temperature')
axes.plot(dates,max_temp,label='Max Temperature')
axes.legend()

# %%
#SEaborn style as default matllllotlib style
sns.set()

# %%
#Simple sine plot
x=np.linspace(0,10,1000)
plt.plot(x,np.sin(x),x,np.cos(x))

# %%
#Relational plots
sns.set(style='dark')
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(15,10))
df=sns.load_dataset('tips')
print(df.head())
sns.lineplot(x='total_bill',y='tip',hue='size',data=df,ax=ax[0]).set_title("LinePlot")
Sct_plt=sns.scatterplot(x='total_bill',y='tip',style='time',data=df,ax=ax[1]).set_title("ScatterPlot")
Sct_plt.figure.savefig('Scatter_plot1.png')
print('plot saved')
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# plot saved

# %%
#Categorical plots
sns.set_style('darkgrid')
fig,ax=plt.subplots(nrows=5,ncols=2)
fig.set_size_inches(18.5,10.5)
df=sns.load_dataset('tips')
sns.barplot(x='sex',y='total_bill',data=df,palette='plasma',estimator=np.std,ax=ax[0,0]).set_title('Bar Plot')
sns.countplot(x='sex',data=df,ax=ax[0,1]).set_title('Count Plot')
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker',ax=ax[1,0]).set_title('Box Plot')
sns.violinplot(x='day',y='total_bill',data=df,hue='sex',split=True,ax=ax[1,1]).set_title('Violin Plot')
sns.stripplot(x='day',y='total_bill',data=df,jitter=True,hue='smoker',dodge=True,ax=ax[2,0]).set_title('Strip Plot')
sns.swarmplot(x='day',y='total_bill',data=df,ax=ax[2,1]).set_title('Swarm Plot')
#Combining violin and swarmplot
sns.violinplot(x='day',y='total_bill',data=df,ax=ax[3,0])
sns.swarmplot(x='day',y='total_bill',data=df,ax=ax[3,0]).set_title('Combined Plot')
#Density plot
sns.kdeplot(df['tip'],ax=ax[3,1])
#boxenplot
sns.boxenplot(x="day",y="total_bill",color="b",scale="linear",data=df,ax=ax[4,0])
#Ridgeplot
sns.pointplot(x='day',y='total_bill',color='b',hue='sex',data=df,ax=ax[4,1])
# Out:
# <ipython-input-7-372584635386>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex',y='total_bill',data=df,palette='plasma',estimator=np.std,ax=ax[0,0]).set_title('Bar Plot')
# <ipython-input-7-372584635386>:18: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x="day",y="total_bill",color="b",scale="linear",data=df,ax=ax[4,0])
# <ipython-input-7-372584635386>:20: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:b'` for the same effect.
#
#   sns.pointplot(x='day',y='total_bill',color='b',hue='sex',data=df,ax=ax[4,1])
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **Distribution plots**  in seaborn is used for examining univariate and bivariate distributions. 4 main types of distribution plots:
#
# joinplot
#
# distplot
#
# pairplot
#
# rugplot

# %%
sns.set_style('whitegrid')
df=sns.load_dataset('iris')
print(df.head())
'''Displot- used for univariant set of observations and visualizes it through'''
sns.distplot(df['petal_length'],kde=True,color='red',bins=30).set_title('Dist Plot')
jointgrid=sns.JointGrid(x='petal_length',y='petal_length',data=df)
jointgrid.plot_joint(sns.scatterplot)
jointgrid.plot_marginals(sns.distplot)
g=sns.jointplot(x='petal_length',y='petal_width',data=df,kind='hex')
g.fig.suptitle('Joint Plot')
g=sns.pairplot(df,hue='species',palette='coolwarm')
g.fig.suptitle('Pair Plot 1')
g.add_legend()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <ipython-input-8-236e6455425f>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'],kde=True,color='red',bins=30).set_title('Dist Plot')
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1886: UserWarning:
#
# ...

# %%
pairgrid=sns.PairGrid(data=df)
pairgrid=pairgrid.map_offdiag(sns.scatterplot)
pairgrid=pairgrid.map_diag(plt.hist)
pairgrid=sns.PairGrid(data=df)
pairgrid=pairgrid.map_upper(sns.scatterplot)
pairgrid=pairgrid.map_diag(plt.hist)
pairgrid=pairgrid.map_lower(sns.kdeplot)
g=sns.PairGrid(df,diag_sharey=False,corner=True)
g.map_lower(sns.scatterplot)
g.map_diag(sns.kdeplot)

# %%
df2=sns.load_dataset('iris')
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
df1=sns.load_dataset('flights')
k=df1.drop('month',axis=1)
df2=sns.load_dataset('iris')
o=df2.drop('species',axis=1)
df11=pd.pivot_table(values='passengers',index='month',columns='year',data=df1)
dfc1=k.corr()
dfc2=o.corr()
sns.heatmap(df11,cmap='viridis',linecolor='r',linewidths=0.5,annot=True,fmt='d',square=True,ax=ax[0,0]).set_title('Heat Map Flights')
sns.heatmap(dfc2,cmap='coolwarm',linecolor='black',linewidths=1,annot=True,ax=ax[0,1]).set_title('Heat Map Iris')
mask1=np.triu(dfc2)
sns.heatmap(dfc2,annot=True,mask=mask1,ax=ax[1,0],cmap='coolwarm').set_title('Heat Map Lower Triangle')
mask2=np.tril(dfc2)
sns.heatmap(dfc2,annot=True,cmap='plasma',mask=mask2,ax=ax[1,1]).set_title('Heat Upper Triangle')
sns.clustermap(df11,cmap='RdYlGn')

# %%
#Exercise(Titanic dataset)
#1. plot histogram for the every class of passengers who survived
#2. plot barplot for the cabin vs fare
#3. plot appropriate graph for embarked city vs survived
#4. plot graph between all the features in a graph
#5. plot heatmap and infer two highly co-related features whith survived

# %%
import seaborn as sns
dft=sns.load_dataset('titanic')
dft.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.histplot(data=dft,x=dft['class'])
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
sns.barplot(data=dft,x=dft['deck'],y=dft['fare'],hue='class')
# Out:
# <Axes: xlabel='deck', ylabel='fare'>

# %%
sns.countplot(data=dft,x='survived',hue='embark_town')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.pairplot(dft)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dft[['sex', 'class', 'who','adult_male','deck','alive','alone','embark_town','embarked']] = dft[['sex', 'class', 'who','adult_male','deck','alive','alone','embark_town','embarked']].apply(LabelEncoder().fit_transform)
co=dft.corr()

# %%
sns.heatmap(co,cmap='coolwarm',linewidths=0.5,annot=True)
# Out:
# <Axes: >
